# %%
import tensorflow as tf                                
import matplotlib.pyplot as plt                                         
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam         
from tensorflow.keras.callbacks import EarlyStopping   
from tensorflow.keras.regularizers import l1, l2      
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Flatten, Dropout,BatchNormalization  
from tensorflow.keras.applications import DenseNet121

# %%
train_data = tf.keras.utils.image_dataset_from_directory(
    '/kaggle/input/tomatoleaf/tomato/train',
    labels='inferred',
    label_mode='categorical',
    image_size=(256, 256),
    batch_size=32)

train_data = train_data.map(lambda x, y: (x / 255.0, y))
# Out:
# Found 10000 files belonging to 10 classes.

# %%
val_data = tf.keras.preprocessing.image_dataset_from_directory(
    '/kaggle/input/tomatoleaf/tomato/val',
    labels='inferred',
    label_mode='categorical',
    image_size=(256, 256),
    batch_size=32)

val_data = val_data.map(lambda x, y: (x / 255.0, y))
# Out:
# Found 1000 files belonging to 10 classes.

# %%
conv = DenseNet121(
    weights='imagenet',
    include_top = False,
    input_shape=(256,256,3),
    pooling='avg'
)

# %%
conv.trainable = False

# %%
model = Sequential()
model.add(conv)
model.add(BatchNormalization())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_data, epochs=100, validation_data=val_data, callbacks=[EarlyStopping(patience=0)], verbose=2)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721628454.350972     129 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 313/313 - 99s - 318ms/step - accuracy: 0.5480 - loss: 1.3763 - val_accuracy: 0.7380 - val_loss: 0.9105
# Epoch 2/100
# 313/313 - 20s - 63ms/step - accuracy: 0.7941 - loss: 0.6584 - val_accuracy: 0.8480 - val_loss: 0.5143
# Epoch 3/100
# 313/313 - 20s - 63ms/step - accuracy: 0.8520 - loss: 0.4686 - val_accuracy: 0.8760 - val_loss: 0.3833
# Epoch 4/100
# 313/313 - 20s - 63ms/step - accuracy: 0.8868 - loss: 0.3554 - val_accuracy: 0.9010 - val_loss: 0.3224
# Epoch 5/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9066 - loss: 0.2917 - val_accuracy: 0.9090 - val_loss: 0.2779
# Epoch 6/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9278 - loss: 0.2425 - val_accuracy: 0.9170 - val_loss: 0.2479
# Epoch 7/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9334 - loss: 0.2101 - val_accuracy: 0.9200 - val_loss: 0.2240
# Epoch 8/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9445 - loss: 0.1781 - val_accuracy: 0.9240 - val_loss: 0.2079
# Epoch 9/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9508 - loss: 0.1607 - val_accuracy: 0.9320 - val_loss: 0.1914
# Epoch 10/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9554 - loss: 0.1403 - val_accuracy: 0.9360 - val_loss: 0.1837
# Epoch 11/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9624 - loss: 0.1189 - val_accuracy: 0.9420 - val_loss: 0.1753
# Epoch 12/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9652 - loss: 0.1122 - val_accuracy: 0.9460 - val_loss: 0.1639
# Epoch 13/100
# 313/313 - 20s - 65ms/step - accuracy: 0.9712 - loss: 0.0953 - val_accuracy: 0.9430 - val_loss: 0.1622
# Epoch 14/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9735 - loss: 0.0891 - val_accuracy: 0.9440 - val_loss: 0.1570
# Epoch 15/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9734 - loss: 0.0855 - val_accuracy: 0.9490 - val_loss: 0.1561
# Epoch 16/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9781 - loss: 0.0743 - val_accuracy: 0.9470 - val_loss: 0.1525
# Epoch 17/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9817 - loss: 0.0644 - val_accuracy: 0.9510 - val_loss: 0.1446
# Epoch 18/100
# 313/313 - 20s - 63ms/step - accuracy: 0.9789 - loss: 0.0641 - val_accuracy: 0.9500 - val_loss: 0.1483

# %%
evaluation = model.evaluate(val_data)
print("Validation Loss:", evaluation[0])
print("Validation Accuracy:", evaluation[1])
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - accuracy: 0.9426 - loss: 0.1674
# Validation Loss: 0.14830702543258667
# Validation Accuracy: 0.949999988079071

# %% [markdown]
# <H1>Recieved Accuracy of 95%</H1>
